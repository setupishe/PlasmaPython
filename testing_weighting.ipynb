# %%
from plasma_classes import *
from plasma_utils import *
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.animation as animation
from tqdm import tqdm

# %%
L = 0.01
N_x = 100
N_p = 10000
h = L/N_x
nodes_grid = np.linspace(0, L, N_x + 1)

# %%
particles_grid = np.linspace(0, L, N_p + 1)

# %%
n0 = 1e17
n1 = n0*N_x/N_p
q = 1.60217e-19
m = 9.1093837e-31
epsilon = 8.85e-12

# %%
particles = Particles(N_p, n1, -q, m)
nodes = Nodes(N_x)

# %%
particles.x = (np.sin(particles_grid*1000)*L)/2+L/2

# %%
particles.normalise(h, 1)

# %%
plt.plot(particles_grid, particles.x)

# %%
plt.hist(particles.x, bins=200)
# %matplotlib inline

# %%
get_rho(nodes, particles)

# %%
plt.plot(nodes_grid, nodes.rho)

# %%
550*q*n1
# Out:
# 0.08811935

# %%
nodes.rho[-1]
# Out:
# -0.0855349038639962
