# %%
from plasma_classes import *
from plasma_utils import *
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.animation as animation
from tqdm import tqdm

# %%
L = 0.01
N_x = 100
N_p = 10000
h = L/N_x
nodes_grid = np.linspace(0, L, N_x + 1)

# %%
particles_grid = np.linspace(0, L, N_p + 1)

# %%
n0 = 1e17
n1 = n0*N_x/N_p
q = 1.60217e-19
m = 9.1093837e-31
epsilon = 8.85e-12

# %%
particles = Particles(N_p, n1, -q, m)
nodes = Nodes(N_x)

# %%
particles.x = (np.sin(particles_grid*1000)*L)/2+L/2

# %%
particles.normalise(h, 1)

# %%
plt.plot(particles_grid, particles.x)

# %%
plt.hist(particles.x, bins=200)
# %matplotlib inline

# %%
get_rho(nodes, particles)
# Out:
# [1.00000000e+15 9.50000008e+14 9.00000067e+14 ... 1.17094045e+14
#  1.59088374e+14 2.01055544e+14]
# [-0.04276733 -0.03555189 -0.02327006 -0.01891622 -0.01641589 -0.01473825
#  -0.01351487 -0.01257472 -0.01182231 -0.01120514 -0.01068798 -0.01024484
#  -0.00986561 -0.00953146 -0.0092362  -0.00897793 -0.00874165 -0.00853164
#  -0.00834309 -0.00816827 -0.00801304 -0.00786664 -0.00783107 -0.0102631
#  -0.01125405 -0.01110156 -0.01095824 -0.01082789 -0.01070466 -0.01059457
#  -0.01048958 -0.01039071 -0.0103078  -0.01022118 -0.01014679 -0.01007778
#  -0.01001323 -0.00995569 -0.0099053  -0.00985167 -0.00981432 -0.0097724
#  -0.0097373  -0.00970936 -0.00968398 -0.00966252 -0.00964391 -0.00963051
#  -0.00962094 -0.00961522 -0.01129568 -0.01282043 -0.01282819 -0.01284108
#  -0.01285908 -0.0128822  -0.01291041 -0.01294449 -0.01298665 -0.01303175
#  -0.01307871 -0.01314402 -0.01320062 -0.01327456 -0.0133535  -0.01343621
#  -0.01352985 -0.0136313  -0.01373568 -0.01386101 -0.0139848  -0.01412304
#  -0.01427524 -0.01443625 -0.01461199 -0.01480092 -0.01500904 -0.01522891
#  -0.01547087 -0.01573868 -0.0160219  -0.01634076 -0.01668182 -0.01706562
#  -0.01748633 -0.01794959 -0.01847735 -0.01906231 -0.01972776 -0.02049412
#  -0.02137371 -0.02241035 -0.02364459 -0.02514749 -0.02703169 -0.02947771
#  -0.03283005 -0.03783318 -0.04654044 -0.07110305 -0.0855349 ]

# %%
plt.plot(nodes_grid, nodes.rho)

# %%
550*q*n1
# Out:
# 0.08811935

# %%
nodes.rho[-1]
# Out:
# -0.0855349038639962
