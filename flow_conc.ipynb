# %%
from plasma_classes import *
from plasma_utils import *
from matplotlib import pyplot as plt
from matplotlib import animation
from tqdm import tqdm

# %%
conc_ion_fluxes = []
conc_electron_fluxes = []
conc_sum_fluxes = []
conc_kinetic_history = []
conc_electric_history = []
conc_summ_history = []

# %%
concentrations = []

# %%
conc_k = np.linspace(0.05, 1, 20)

# %%
for i in range(len(conc_k)):
    L = 1e-2
    N_x = 200
    N_p = 10000
    h = L/N_x
    tau = 2e-13
    n0 = 1e17*conc_k[i]
    concentrations.append(n0)
    n1 = n0*N_x/N_p
    q = 1.60217e-19
    m_e = 9.1093837e-31
    m_i = 1.672e-27*131
    epsilon = 8.85e-12
    T_e = 11600*20
    #temps.append(T_e)
    T_i = 600
    k_b = 1.38e-23
    v_t_e = math.sqrt(3*k_b*T_e/m_e)
    vmin_e = -3*v_t_e
    vmax_e = 3*v_t_e
    v_t_i = math.sqrt(3*k_b*T_i/m_i)
    vmin_i = -3*v_t_i
    vmax_i = 3*v_t_i
    ions = Particles(N_p, n1, q, m_i)
    electrons = Particles(N_p, n1, -q, m_e)
    nodes = Nodes(N_x)
    left_wall = Wall(0, L/10, 0, h, "left")
    right_wall = Wall(9*L/10, L, 0, h, "right")
    walls = (left_wall, right_wall)

    set_homogeneous(electrons, left_wall.right*h, right_wall.left*h)
    set_homogeneous(ions, left_wall.right*h, right_wall.left*h)
    set_distr(electrons, Maxwell(T_e, k_b, m_e), vmin_e, vmax_e, 1000)
    set_distr(ions, Maxwell(T_i, k_b, m_i), vmin_i, vmax_i, 1000)
    electrons.normalise(h, tau)
    ions.normalise(h, tau)
    get_rho(nodes, electrons)
    get_rho(nodes, ions)
    calc_fields(nodes, h, epsilon)
    accel(electrons, nodes, L, h, tau, zerostep=True)
    accel(ions, nodes, L, h, tau, zerostep=True)
    n = 50000
    
    for t in tqdm(range(n)):
        try:
            move(electrons, nodes, consistency=True)
            move(ions, nodes, consistency=True)
        except Exception:
            print("number of iteration: ", t)
            break

        nodes.rho *= 0
        energy_dict = {"electric": [], "kinetic": [], "summ": [], "h": h, "tau": tau}
        account_walls(electrons, walls, Energy=energy_dict, nodes=nodes)
        account_walls(ions, walls, Energy=energy_dict, nodes=nodes)
        get_rho(nodes, electrons)
        get_rho(nodes, ions)
        for wall in walls:
            for particles in wall.particles_lst:
                get_rho(nodes, particles)
        
        calc_fields(nodes, h, epsilon, periodic=True)
        conc_electric_history.append(sum(energy_dict["electric"]))
        accel(electrons, nodes, L, h, tau)
        accel(ions, nodes, L, h, tau)
        conc_kinetic_history.append(sum(energy_dict["kinetic"]))

    for i in range(n):
        conc_summ_history.append(conc_kinetic_history[i] + conc_electric_history[i])

    conc_electron_fluxes.append(N_p-electrons.n_macro)
    conc_ion_fluxes.append(N_p-ions.n_macro)
# Out:
#   6%|▌         | 2932/50000 [01:23<22:26, 34.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 44
#      41 accel(ions, nodes, L, h, tau, zerostep=True)
#      42 n = 50000
# ---> 44 for t in tqdm(range(n)):
#      45     try:
#      46         move(electrons, nodes, consistency=True)
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\tqdm\std.py:1205, in tqdm.__iter__(self)
#    1203 dt = cur_t - last_print_t
#    1204 if dt >= mininterval and cur_t >= min_start_t:
# -> 1205     self.update(n - last_print_n)
#    1206     last_print_n = self.last_print_n
#    1207     last_print_t = self.last_print_t
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\tqdm\std.py:1256, in tqdm.update(self, n)
#    1254     self._ema_dn(dn)
#    1255     self._ema_dt(dt)
# -> 1256 self.refresh(lock_args=self.lock_args)
#    1257 if self.dynamic_miniters:
#    1258     # If no `miniters` was specified, adjust automatically to the
#    1259     # maximum iteration rate seen so far between two prints.
#    1260     # e.g.: After running `tqdm.update(5)`, subsequent
#    1261     # calls to `tqdm.update()` will only cause an update after
#    1262     # at least 5 more iterations.
#    1263     if self.maxinterval and dt >= self.maxinterval:
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\tqdm\std.py:1361, in tqdm.refresh(self, nolock, lock_args)
#    1359     else:
#    1360         self._lock.acquire()
# -> 1361 self.display()
#    1362 if not nolock:
#    1363     self._lock.release()
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\tqdm\std.py:1509, in tqdm.display(self, msg, pos)
#    1507 if pos:
#    1508     self.moveto(pos)
# -> 1509 self.sp(self.__str__() if msg is None else msg)
#    1510 if pos:
#    1511     self.moveto(-pos)
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\tqdm\std.py:350, in tqdm.status_printer.<locals>.print_status(s)
#     348 def print_status(s):
#     349     len_s = disp_len(s)
# --> 350     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     351     last_len[0] = len_s
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\tqdm\std.py:344, in tqdm.status_printer.<locals>.fp_write(s)
#     342 def fp_write(s):
#     343     fp.write(_unicode(s))
# --> 344     fp_flush()
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\tqdm\utils.py:145, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     143 def inner(*args, **kwargs):
#     144     try:
# --> 145         return func(*args, **kwargs)
#     146     except OSError as e:
#     147         if e.errno != 5:
#
# File c:\Users\setup\Desktop\PlasmaPython\.venv\lib\site-packages\ipykernel\iostream.py:497, in OutStream.flush(self)
#     495     self.pub_thread.schedule(evt.set)
#     496     # and give a timeout to avoid
# --> 497     if not evt.wait(self.flush_timeout):
#     498         # write directly to __stderr__ instead of warning because
#     499         # if this is happening sys.stderr may be the problem.
#     500         print("IOStream.flush timed out", file=sys.__stderr__)
#     501 else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
conc_electron_fluxes = np.array(conc_electron_fluxes)
conc_ion_fluxes = np.array(conc_ion_fluxes)

# %%
conc_electric_history = np.array(conc_electric_history)
conc_kinetic_history = np.array(conc_kinetic_history)
conc_summ_history = np.array(conc_summ_history)

# %%
conc_electric_history = conc_electric_history.reshape(20, 15000)
conc_kinetic_history = conc_kinetic_history.reshape(20, 15000)
conc_summ_history = conc_summ_history.reshape(20, 15000)

# %%
conc_electric_flux = [np.mean(conc_electric_history[i]) for i in range(9)]
conc_kinetic_flux = np.array([np.mean(conc_kinetic_history[i]) for i in range(9)])
conc_summ_flux = [np.mean(conc_summ_history[i]) for i in range(9)]

# %%
concentrations = np.array(concentrations)

# %%
#plt.scatter(concentrations, conc_electric_flux/conc_electric_flux[0], label="electric")
plt.scatter(concentrations, conc_kinetic_flux/conc_kinetic_flux[0], label="kinetic")
#plt.scatter(concentrations, conc_summ_flux/conc_summ_flux[0], label="summ")
plt.grid()
plt.xlabel(r"$n, м^{-3}$")
plt.ylabel(f"$E/E_0$")
plt.title("Зависимость потока энергии от концентрации плазмы")
# Out:
# Text(0.5, 1.0, 'Зависимость потока энергии от концентрации плазмы')

# %%
plt.scatter(concentrations, conc_electron_fluxes/conc_electron_fluxes[-1], label="электроны")
plt.scatter(concentrations, conc_ion_fluxes/conc_ion_fluxes[-1], label="ионы")
plt.legend()
plt.grid()
plt.xlabel(r"$n, м^{-3}$")
plt.ylabel(f"$F/F_0$")
plt.title("Зависимость потоков частиц от концентрации плазмы")
# Out:
# Text(0.5, 1.0, 'Зависимость потоков частиц от концентрации плазмы')

# %%
import os

# %%
def save_array_to_file(np_array, filename):
    with open(filename, 'w') as f:
        for float_value in np_array:
            f.write(f"{float_value}\n")

def read_array_from_file(filename):
    if not os.path.exists(filename):
        raise FileNotFoundError(f"{filename} not found")

    float_list = []
    with open(filename, 'r') as f:
        for line in f:
            float_list.append(float(line.strip()))

    return np.array(float_list)

# %%
save_array_to_file(conc_kinetic_flux, "conc_kinetic")
save_array_to_file(concentrations, "concentrations")
save_array_to_file(conc_electron_fluxes, "conc_electron_fluxes")
save_array_to_file(conc_ion_fluxes, "conc_ion_fluxes")
