# %%
import fix_sys_path
from plasma_classes import *
from plasma_utils import *
from matplotlib import pyplot as plt

# %%
T = 11600
k_b = 1.38e-23
m = 9.1093837e-31
alpha = -m/(2*k_b*T)
v_t = math.sqrt(3*k_b*T/m)
vmin = -4*v_t
vmax = 4*v_t

# %%
v_t
# Out:
# 726080.3229918289

# %%
alpha
# Out:
# -2.845259776361819e-12

# %%
particles = Particles(1000, 1, 1, 1)

# %%
integral = get_integral(Maxwell(T, k_b, m), vmin, vmax, 100000)

# %%
set_distr(particles, integral)

# %%
v_t
# Out:
# 726080.3229918289

# %%
np.mean(particles.v)/1e6
# Out:
# -0.012954841292198845

# %%
plt.hist(particles.v, bins=50)
# %matplotlib inline

# %%
theory = np.random.normal(0, 1/math.sqrt(-alpha), particles.n_macro)

# %%
plt.hist(theory, bins=50)
# %matplotlib inline

# %%
np.mean(theory)
# Out:
# -2.320363135175924e-11

# %%
set_homogeneous(particles, 10)

# %%
res = get_distr(particles, 1, 3)
plt.hist(res, bins=50)
# %matplotlib inline
